# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import string
import spacy
from matplotlib.pyplot import imread
from wordcloud import WordCloud, STOPWORDS
# %matplotlib inline

# %%
reviews = pd.read_csv('iphone_4s_review.csv',encoding='Latin-1')
reviews
# Out:
#        Ratings                                            Reviews
# 0          5.0  These are still going strong after 3 months of...
# 1          5.0  Hey! you know that Chance scouted out the loca...
# 2          5.0  All moving pieces work as intended. The pieces...
# 3          3.0  This book made me want to read more.  I loved ...
# 4          5.0  This book was so very excellent. To see what D...
# ...        ...                                                ...
# 50141      5.0                      Absolutely brilliantREAD MORE
# 50142      5.0  Superb phone. This is my 4th iPhone, I feel SE...
# 50143      5.0                                 very niceREAD MORE
# 50144      5.0       Loving it as of now. Good Product .READ MORE
# 50145      5.0                      NiceElegant ElectricREAD MORE
#
# [50146 rows x 2 columns]

# %%
reviews['Reviews'] = reviews['Reviews'].astype(str)

# %% [raw]
# reviews.dtypes

# %%
reviews = [word.strip() for word in reviews['Reviews']] 
reviews = [word for word in reviews if word]
reviews
# Out:
# ['These are still going strong after 3 months of use. I find some solar products fail soon but this has not.\nIf anything changes I shall update, for now I can suggest these lights!',
# ...

# %%
review_text = ' '.join(reviews)
review_text[0:1000]
# Out:
# "These are still going strong after 3 months of use. I find some solar products fail soon but this has not.\nIf anything changes I shall update, for now I can suggest these lights! Hey! you know that Chance scouted out the location of the canyon when he was haveing her plane connections delayed and rerouted.\nI loved the way L. Howard kept the character of Chance true to form from one story to the next.\nAlso if John is old enough to have a girlfriend he is old enough to get caught up in some machinations that needs Zane and Chance to rescue him and set him on the path of his two uncles'- besides Zane needs to produce another daughter and Chance one to put them into a hilarious competition [aided and abetted by their wives]\nthere are still enough up close stories to be told with Mary and Wolf still in the background -- and lets go back in time to Michael's and Josh's stories.\nI, along with so many others, agree that this has been the best family series ever written - with all of th
# ...

# %%
no_punc_text=review_text.translate(str.maketrans('','',string.punctuation))
no_punc_text[0:1000]
# Out:
# 'These are still going strong after 3 months of use I find some solar products fail soon but this has not\nIf anything changes I shall update for now I can suggest these lights Hey you know that Chance scouted out the location of the canyon when he was haveing her plane connections delayed and rerouted\nI loved the way L Howard kept the character of Chance true to form from one story to the next\nAlso if John is old enough to have a girlfriend he is old enough to get caught up in some machinations that needs Zane and Chance to rescue him and set him on the path of his two uncles besides Zane needs to produce another daughter and Chance one to put them into a hilarious competition aided and abetted by their wives\nthere are still enough up close stories to be told with Mary and Wolf still in the background  and lets go back in time to Michaels and Joshs stories\nI along with so many others agree that this has been the best family series ever written  with all of the ladies well matche
# ...

# %%
from nltk.tokenize import word_tokenize
text_tokens=word_tokenize(no_punc_text)
print(text_tokens[0:1000])
# Out:
# ['These', 'are', 'still', 'going', 'strong', 'after', '3', 'months', 'of', 'use', 'I', 'find', 'some', 'solar', 'products', 'fail', 'soon', 'but', 'this', 'has', 'not', 'If', 'anything', 'changes', 'I', 'shall', 'update', 'for', 'now', 'I', 'can', 'suggest', 'these', 'lights', 'Hey', 'you', 'know', 'that', 'Chance', 'scouted', 'out', 'the', 'location', 'of', 'the', 'canyon', 'when', 'he', 'was', 'haveing', 'her', 'plane', 'connections', 'delayed', 'and', 'rerouted', 'I', 'loved', 'the', 'way', 'L', 'Howard', 'kept', 'the', 'character', 'of', 'Chance', 'true', 'to', 'form', 'from', 'one', 'story', 'to', 'the', 'next', 'Also', 'if', 'John', 'is', 'old', 'enough', 'to', 'have', 'a', 'girlfriend', 'he', 'is', 'old', 'enough', 'to', 'get', 'caught', 'up', 'in', 'some', 'machinations', 'that', 'needs', 'Zane', 'and', 'Chance', 'to', 'rescue', 'him', 'and', 'set', 'him', 'on', 'the', 'path', 'of', 'his', 'two', 'uncles', 'besides', 'Zane', 'needs', 'to', 'produce', 'another', 'daughter', 'a
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
my_stop_words=stopwords.words('english')

sw_list = ['rt','ye','yeah','haha','Yes','I']
my_stop_words.extend(sw_list)

no_stop_tokens=[word for word in text_tokens if not word in my_stop_words]
print(no_stop_tokens[0:1000])
# Out:
# ['These', 'still', 'going', 'strong', '3', 'months', 'use', 'find', 'solar', 'products', 'fail', 'soon', 'If', 'anything', 'changes', 'shall', 'update', 'suggest', 'lights', 'Hey', 'know', 'Chance', 'scouted', 'location', 'canyon', 'haveing', 'plane', 'connections', 'delayed', 'rerouted', 'loved', 'way', 'L', 'Howard', 'kept', 'character', 'Chance', 'true', 'form', 'one', 'story', 'next', 'Also', 'John', 'old', 'enough', 'girlfriend', 'old', 'enough', 'get', 'caught', 'machinations', 'needs', 'Zane', 'Chance', 'rescue', 'set', 'path', 'two', 'uncles', 'besides', 'Zane', 'needs', 'produce', 'another', 'daughter', 'Chance', 'one', 'put', 'hilarious', 'competition', 'aided', 'abetted', 'wives', 'still', 'enough', 'close', 'stories', 'told', 'Mary', 'Wolf', 'still', 'background', 'lets', 'go', 'back', 'time', 'Michaels', 'Joshs', 'stories', 'along', 'many', 'others', 'agree', 'best', 'family', 'series', 'ever', 'written', 'ladies', 'well', 'matched', 'Mackenzie', 'men', 'family', 'cant',
# ...

# %%
# Normalize the data
lower_words=[Text.lower() for Text in no_stop_tokens]
print(lower_words[100:200])
# Out:
# ['well', 'matched', 'mackenzie', 'men', 'family', 'cant', 'stand', 'still', 'classics', 'with', 'sunny', 'willing', 'put', 'life', 'line', 'chance', 'great', 'job', 'breaking', 'reserve', 'teaching', 'love', 'love', 'comes', 'giving', 'love', 'woman', 'willing', 'take', 'care', 'selfpreservation', 'grin', 'dragging', 'man', 'realizing', 'worth', 'l', 'howard', 'spoiled', 'us', 'mackenzie', 'men', 'dont', 'stop', 'highly', 'recommended', 'definitely', 'a', 'keeper', 'for', 'any', 'library', 'all', 'moving', 'pieces', 'work', 'intended', 'the', 'pieces', 'sturdy', 'keep', 'moving', 'long', 'time', 'this', 'book', 'made', 'want', 'read', 'loved', 'would', 'recommend', 'iti', 'read', 'book', 'middle', 'night', 'great', 'the', 'story', 'well', 'told', 'characters', 'strong', 'would', 'recommend', 'bookgreat', 'book', 'great', 'characters', 'love', 'book', 'cant', 'wait', 'read', 'next', 'one', 'cant', 'wait', 'read']

# %%
# Stemming (Optional)
from nltk.stem import PorterStemmer
ps=PorterStemmer()
stemmed_tokens=[ps.stem(word) for word in lower_words]
print(stemmed_tokens[100:200])
# Out:
# ['well', 'match', 'mackenzi', 'men', 'famili', 'cant', 'stand', 'still', 'classic', 'with', 'sunni', 'will', 'put', 'life', 'line', 'chanc', 'great', 'job', 'break', 'reserv', 'teach', 'love', 'love', 'come', 'give', 'love', 'woman', 'will', 'take', 'care', 'selfpreserv', 'grin', 'drag', 'man', 'realiz', 'worth', 'l', 'howard', 'spoil', 'us', 'mackenzi', 'men', 'dont', 'stop', 'highli', 'recommend', 'definit', 'a', 'keeper', 'for', 'ani', 'librari', 'all', 'move', 'piec', 'work', 'intend', 'the', 'piec', 'sturdi', 'keep', 'move', 'long', 'time', 'thi', 'book', 'made', 'want', 'read', 'love', 'would', 'recommend', 'iti', 'read', 'book', 'middl', 'night', 'great', 'the', 'stori', 'well', 'told', 'charact', 'strong', 'would', 'recommend', 'bookgreat', 'book', 'great', 'charact', 'love', 'book', 'cant', 'wait', 'read', 'next', 'one', 'cant', 'wait', 'read']

# %%
clean_tweets=' '.join(stemmed_tokens)
clean_tweets[0:1000]
# Out:
# 'these still go strong 3 month use find solar product fail soon if anyth chang shall updat suggest light hey know chanc scout locat canyon have plane connect delay rerout love way l howard kept charact chanc true form one stori next also john old enough girlfriend old enough get caught machin need zane chanc rescu set path two uncl besid zane need produc anoth daughter chanc one put hilari competit aid abet wive still enough close stori told mari wolf still background let go back time michael josh stori along mani other agre best famili seri ever written ladi well match mackenzi men famili cant stand still classic with sunni will put life line chanc great job break reserv teach love love come give love woman will take care selfpreserv grin drag man realiz worth l howard spoil us mackenzi men dont stop highli recommend definit a keeper for ani librari all move piec work intend the piec sturdi keep move long time thi book made want read love would recommend iti read book middl night gr
# ...
